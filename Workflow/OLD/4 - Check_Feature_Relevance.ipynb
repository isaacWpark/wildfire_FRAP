# %% [markdown]
# # Identify Relevant Features
#
# ## Single Feature Set Example

# %%
import os 
import pandas as pd
from tsraster.calculate import checkRelevance
import tsraster.prep as tr


# read csv extracted features
features = pd.read_csv(r"../Data/Examples/3month_features/extracted_features.csv")

# %% [markdown]
# Read in target data (variable you want to predict).

# %%
#%% path to folder holding target data raster
target_variable = r"C:\Users\mmann\Documents\wildfire_FRAP\Data\Examples\3month_fire"

target_data = tr.targetData(target_variable)

# %%
#check for relevance
relevance = checkRelevance(features, target_data)
relevance
# Out:
#                                                  feature  type        p_value  \
# feature
# aet-value__mean                          aet-value__mean  real  3.816483e-297
# aet-value__quantile__q_0.95  aet-value__quantile__q_0.95  real  4.082583e-288
# aet-value__maximum                    aet-value__maximum  real  3.366128e-286
# aet-value__minimum                    aet-value__minimum  real  1.029450e-254
# aet-value__quantile__q_0.15  aet-value__quantile__q_0.15  real  1.916881e-229
#
#                              relevant
# feature
# aet-value__mean                  True
# aet-value__quantile__q_0.95      True
# aet-value__maximum               True
# aet-value__minimum               True
# aet-value__quantile__q_0.15      True

# %% [markdown]
# ## Multiple Feature Sets Example
#
# In this case we have multiple data sets that we need to summarize. Here is an example of temperature and precipitation.
# ```
# temprature
#     2005
#         tmx-200501.tif
#         tmx-200502.tif
#         tmx-200503.tif ...
#     2006
#         tmx-200601.tif
#         tmx-200602.tif
#         tmx-200603.tif...
# precip
#     2005
#         ppt-200501.tif
#         ppt-200502.tif
#         ppt-200503.tif ...
# ```

# %%
# append all features to one dataframe 
path = r'F:/5year/'

all_files = [os.path.join(root, name)
             for root, dirs, files in os.walk(path)
             for name in files
             if name.endswith(( "features.csv"))]

df_from_each_file = (pd.read_csv(f) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file,axis=1, ignore_index=False)
concatenated_df.columns
# Out:
# Index(['id',
#        'aet-value__agg_linear_trend__f_agg_"max"__chunk_len_6__attr_"slope"',
#        'aet-value__agg_linear_trend__f_agg_"min"__chunk_len_6__attr_"slope"',
#        'aet-value__count_above_mean', 'aet-value__count_below_mean',
#        'aet-value__last_location_of_maximum',
#        'aet-value__last_location_of_minimum',
#        'aet-value__longest_strike_above_mean',
#        'aet-value__longest_strike_below_mean', 'aet-value__maximum',
#        ...
#        'tmx-value__number_cwt_peaks__n_12', 'tmx-value__number_cwt_peaks__n_6',
#        'tmx-value__quantile__q_0.05', 'tmx-value__quantile__q_0.15',
#        'tmx-value__quantile__q_0.85', 'tmx-value__quantile__q_0.95',
#        'tmx-value__ratio_beyond_r_sigma__r_2',
#        'tmx-value__ratio_beyond_r_sigma__r_3', 'tmx-value__skewness',
#        'tmx-value__sum_values'],
#       dtype='object', length=144)

# %%
#%% read target data
target_variable = "F:/5year/Fires/"

target_data = tr.targetData(target_variable)

# %%
checkRelevance(concatenated_df, target_data)
# Out:
#                                                                                               feature  \
# feature
# pet-value__agg_linear_trend__f_agg_"max"__chunk...  pet-value__agg_linear_trend__f_agg_"max"__chun...
# ppt-value__longest_strike_above_mean                             ppt-value__longest_strike_above_mean
# ppt-value__last_location_of_minimum                               ppt-value__last_location_of_minimum
# ppt-value__last_location_of_maximum                               ppt-value__last_location_of_maximum
# ppt-value__count_below_mean                                               ppt-value__count_below_mean
# ppt-value__count_above_mean                                               ppt-value__count_above_mean
# ppt-value__agg_linear_trend__f_agg_"min"__chunk...  ppt-value__agg_linear_trend__f_agg_"min"__chun...
# ppt-value__agg_linear_trend__f_agg_"max"__chunk...  ppt-value__agg_linear_trend__f_agg_"max"__chun...
# pet-value__sum_values                                                           pet-value__sum_values
# pet-value__skewness                                                               pet-value__skewness
# pet-value__quantile__q_0.95                                               pet-value__quantile__q_0.95
# pet-value__quantile__q_0.85                                               pet-value__quantile__q_0.85
# pet-value__quantile__q_0.15                                               pet-value__quantile__q_0.15
# pet-value__quantile__q_0.05                                               pet-value__quantile__q_0.05
# ppt-value__longest_strike_below_mean                             ppt-value__longest_strike_below_mean
# pet-value__number_cwt_peaks__n_6                                     pet-value__number_cwt_peaks__n_6
# pet-value__minimum                                                                 pet-value__minimum
# pet-value__median                                                                   pet-value__median
# pet-value__mean_change                                                         pet-value__mean_change
# pet-value__mean                                                                       pet-value__mean
# pet-value__maximum                                                                 pet-value__maximum
# pet-value__longest_strike_below_mean                             pet-value__longest_strike_below_mean
# pet-value__longest_strike_above_mean                             pet-value__longest_strike_above_mean
# pet-value__last_location_of_minimum                               pet-value__last_location_of_minimum
# pet-value__last_location_of_maximum                               pet-value__last_location_of_maximum
# pet-value__count_below_mean                                               pet-value__count_below_mean
# pet-value__count_above_mean                                               pet-value__count_above_mean
# pet-value__agg_linear_trend__f_agg_"min"__chunk...  pet-value__agg_linear_trend__f_agg_"min"__chun...
# tmx-value__sum_values                                                           tmx-value__sum_values
# pet-value__number_cwt_peaks__n_12                                   pet-value__number_cwt_peaks__n_12
# ...                                                                                               ...
# pck-value__last_location_of_maximum                               pck-value__last_location_of_maximum
# pck-value__count_below_mean                                               pck-value__count_below_mean
# pck-value__count_above_mean                                               pck-value__count_above_mean
# tmx-value__skewness                                                               tmx-value__skewness
# pck-value__agg_linear_trend__f_agg_"max"__chunk...  pck-value__agg_linear_trend__f_agg_"max"__chun...
# cwd-value__sum_values                                                           cwd-value__sum_values
# cwd-value__skewness                                                               cwd-value__skewness
# cwd-value__ratio_beyond_r_sigma__r_3                             cwd-value__ratio_beyond_r_sigma__r_3
# cwd-value__ratio_beyond_r_sigma__r_2                             cwd-value__ratio_beyond_r_sigma__r_2
# cwd-value__quantile__q_0.95                                               cwd-value__quantile__q_0.95
# cwd-value__quantile__q_0.85                                               cwd-value__quantile__q_0.85
# cwd-value__quantile__q_0.15                                               cwd-value__quantile__q_0.15
# cwd-value__quantile__q_0.05                                               cwd-value__quantile__q_0.05
# cwd-value__number_cwt_peaks__n_6                                     cwd-value__number_cwt_peaks__n_6
# cwd-value__number_cwt_peaks__n_12                                   cwd-value__number_cwt_peaks__n_12
# cwd-value__minimum                                                                 cwd-value__minimum
# cwd-value__median                                                                   cwd-value__median
# cwd-value__mean                                                                       cwd-value__mean
# tmx-value__quantile__q_0.85                                               tmx-value__quantile__q_0.85
# aet-value__ratio_beyond_r_sigma__r_3                             aet-value__ratio_beyond_r_sigma__r_3
# aet-value__agg_linear_trend__f_agg_"max"__chunk...  aet-value__agg_linear_trend__f_agg_"max"__chun...
# pck-value__median                                                                   pck-value__median
# pck-value__agg_linear_trend__f_agg_"min"__chunk...  pck-value__agg_linear_trend__f_agg_"min"__chun...
# tmx-value__ratio_beyond_r_sigma__r_2                             tmx-value__ratio_beyond_r_sigma__r_2
# tmx-value__ratio_beyond_r_sigma__r_3                             tmx-value__ratio_beyond_r_sigma__r_3
# pck-value__minimum                                                                 pck-value__minimum
# pck-value__quantile__q_0.05                                               pck-value__quantile__q_0.05
# pck-value__quantile__q_0.15                                               pck-value__quantile__q_0.15
# pet-value__ratio_beyond_r_sigma__r_2                             pet-value__ratio_beyond_r_sigma__r_2
# pet-value__ratio_beyond_r_sigma__r_3                             pet-value__ratio_beyond_r_sigma__r_3
#
#                                                         type        p_value  \
# feature
# pet-value__agg_linear_trend__f_agg_"max"__chunk...      real   0.000000e+00
# ppt-value__longest_strike_above_mean                    real   0.000000e+00
# ppt-value__last_location_of_minimum                     real   0.000000e+00
# ppt-value__last_location_of_maximum                     real   0.000000e+00
# ppt-value__count_below_mean                             real   0.000000e+00
# ppt-value__count_above_mean                             real   0.000000e+00
# ppt-value__agg_linear_trend__f_agg_"min"__chunk...      real   0.000000e+00
# ppt-value__agg_linear_trend__f_agg_"max"__chunk...      real   0.000000e+00
# pet-value__sum_values                                   real   0.000000e+00
# pet-value__skewness                                     real   0.000000e+00
# pet-value__quantile__q_0.95                             real   0.000000e+00
# pet-value__quantile__q_0.85                             real   0.000000e+00
# pet-value__quantile__q_0.15                             real   0.000000e+00
# pet-value__quantile__q_0.05                             real   0.000000e+00
# ppt-value__longest_strike_below_mean                    real   0.000000e+00
# pet-value__number_cwt_peaks__n_6                        real   0.000000e+00
# pet-value__minimum                                      real   0.000000e+00
# pet-value__median                                       real   0.000000e+00
# pet-value__mean_change                                  real   0.000000e+00
# pet-value__mean                                         real   0.000000e+00
# pet-value__maximum                                      real   0.000000e+00
# pet-value__longest_strike_below_mean                    real   0.000000e+00
# pet-value__longest_strike_above_mean                    real   0.000000e+00
# pet-value__last_location_of_minimum                     real   0.000000e+00
# pet-value__last_location_of_maximum                     real   0.000000e+00
# pet-value__count_below_mean                             real   0.000000e+00
# pet-value__count_above_mean                             real   0.000000e+00
# pet-value__agg_linear_trend__f_agg_"min"__chunk...      real   0.000000e+00
# tmx-value__sum_values                                   real   0.000000e+00
# pet-value__number_cwt_peaks__n_12                       real   0.000000e+00
# ...                                                      ...            ...
# pck-value__last_location_of_maximum                     real   0.000000e+00
# pck-value__count_below_mean                             real   0.000000e+00
# pck-value__count_above_mean                             real   0.000000e+00
# tmx-value__skewness                                     real   0.000000e+00
# pck-value__agg_linear_trend__f_agg_"max"__chunk...      real   0.000000e+00
# cwd-value__sum_values                                   real   0.000000e+00
# cwd-value__skewness                                     real   0.000000e+00
# cwd-value__ratio_beyond_r_sigma__r_3                    real   0.000000e+00
# cwd-value__ratio_beyond_r_sigma__r_2                    real   0.000000e+00
# cwd-value__quantile__q_0.95                             real   0.000000e+00
# cwd-value__quantile__q_0.85                             real   0.000000e+00
# cwd-value__quantile__q_0.15                             real   0.000000e+00
# cwd-value__quantile__q_0.05                             real   0.000000e+00
# cwd-value__number_cwt_peaks__n_6                        real   0.000000e+00
# cwd-value__number_cwt_peaks__n_12                       real   0.000000e+00
# cwd-value__minimum                                      real   0.000000e+00
# cwd-value__median                                       real   0.000000e+00
# cwd-value__mean                                         real   0.000000e+00
# tmx-value__quantile__q_0.85                             real   0.000000e+00
# aet-value__ratio_beyond_r_sigma__r_3                    real  1.293376e-179
# aet-value__agg_linear_trend__f_agg_"max"__chunk...      real  1.289458e-153
# pck-value__median                                       real   2.052450e-18
# pck-value__agg_linear_trend__f_agg_"min"__chunk...      real   5.587999e-07
# tmx-value__ratio_beyond_r_sigma__r_2                    real   7.744631e-01
# tmx-value__ratio_beyond_r_sigma__r_3                  binary   1.000000e+00
# pck-value__minimum                                  constant            NaN
# pck-value__quantile__q_0.05                         constant            NaN
# pck-value__quantile__q_0.15                         constant            NaN
# pet-value__ratio_beyond_r_sigma__r_2                constant            NaN
# pet-value__ratio_beyond_r_sigma__r_3                constant            NaN
#
#                                                     relevant
# feature
# pet-value__agg_linear_trend__f_agg_"max"__chunk...      True
# ppt-value__longest_strike_above_mean                    True
# ppt-value__last_location_of_minimum                     True
# ppt-value__last_location_of_maximum                     True
# ppt-value__count_below_mean                             True
# ppt-value__count_above_mean                             True
# ppt-value__agg_linear_trend__f_agg_"min"__chunk...      True
# ppt-value__agg_linear_trend__f_agg_"max"__chunk...      True
# pet-value__sum_values                                   True
# pet-value__skewness                                     True
# pet-value__quantile__q_0.95                             True
# pet-value__quantile__q_0.85                             True
# pet-value__quantile__q_0.15                             True
# pet-value__quantile__q_0.05                             True
# ppt-value__longest_strike_below_mean                    True
# pet-value__number_cwt_peaks__n_6                        True
# pet-value__minimum                                      True
# pet-value__median                                       True
# pet-value__mean_change                                  True
# pet-value__mean                                         True
# pet-value__maximum                                      True
# pet-value__longest_strike_below_mean                    True
# pet-value__longest_strike_above_mean                    True
# pet-value__last_location_of_minimum                     True
# pet-value__last_location_of_maximum                     True
# pet-value__count_below_mean                             True
# pet-value__count_above_mean                             True
# pet-value__agg_linear_trend__f_agg_"min"__chunk...      True
# tmx-value__sum_values                                   True
# pet-value__number_cwt_peaks__n_12                       True
# ...                                                      ...
# pck-value__last_location_of_maximum                     True
# pck-value__count_below_mean                             True
# pck-value__count_above_mean                             True
# tmx-value__skewness                                     True
# pck-value__agg_linear_trend__f_agg_"max"__chunk...      True
# cwd-value__sum_values                                   True
# cwd-value__skewness                                     True
# cwd-value__ratio_beyond_r_sigma__r_3                    True
# cwd-value__ratio_beyond_r_sigma__r_2                    True
# cwd-value__quantile__q_0.95                             True
# cwd-value__quantile__q_0.85                             True
# cwd-value__quantile__q_0.15                             True
# cwd-value__quantile__q_0.05                             True
# cwd-value__number_cwt_peaks__n_6                        True
# cwd-value__number_cwt_peaks__n_12                       True
# cwd-value__minimum                                      True
# cwd-value__median                                       True
# cwd-value__mean                                         True
# tmx-value__quantile__q_0.85                             True
# aet-value__ratio_beyond_r_sigma__r_3                    True
# aet-value__agg_linear_trend__f_agg_"max"__chunk...      True
# pck-value__median                                       True
# pck-value__agg_linear_trend__f_agg_"min"__chunk...      True
# tmx-value__ratio_beyond_r_sigma__r_2                   False
# tmx-value__ratio_beyond_r_sigma__r_3                   False
# pck-value__minimum                                     False
# pck-value__quantile__q_0.05                            False
# pck-value__quantile__q_0.15                            False
# pet-value__ratio_beyond_r_sigma__r_2                   False
# pet-value__ratio_beyond_r_sigma__r_3                   False
#
# [138 rows x 4 columns]
